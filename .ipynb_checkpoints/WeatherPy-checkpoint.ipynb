# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 643

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}{city}&appid={weather_api_key}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        city_weather = city_weather.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": (city.title()), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

#     # If an error is experienced, skip the city
    except KeyError as e:
        print(f"City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | abha
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | nanortalik
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | lushunkou
# City not found. Skipping...
# Processing Record 7 of Set 1 | guerrero negro
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | havre-saint-pierre
# Processing Record 10 of Set 1 | ulety
# Processing Record 11 of Set 1 | cayenne
# Processing Record 12 of Set 1 | bathsheba
# Processing Record 13 of Set 1 | el dorado
# Processing Record 14 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | vao
# Processing Record 19 of Set 1 | broken hill
# Processing Record 20 of Set 1 | kieta
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | leningradskiy
# Processing Record 27 of Set 1 | neuquen
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | shimoda
# Processing Record 31 of Set 1 | grindavik
# Processing Record 32 of Set 1 | tessalit
# Processing Record 33 of Set 1 | beira
# Processing Record 34 of Set 1 | bintulu
# Processing Record 35 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | arifwala
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | malibu
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | thoen
# Processing Record 44 of Set 1 | san quintin
# Processing Record 45 of Set 1 | ouegoa
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | kurchum
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 0 of Set 2 | kaeo
# Processing Record 1 of Set 2 | manggar
# Processing Record 2 of Set 2 | iqaluit
# Processing Record 3 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | yumen
# Processing Record 5 of Set 2 | mogochin
# City not found. Skipping...
# Processing Record 6 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 2 | vanavara
# Processing Record 8 of Set 2 | venado tuerto
# Processing Record 9 of Set 2 | san vicente
# Processing Record 10 of Set 2 | nuuk
# Processing Record 11 of Set 2 | lebu
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | evensk
# Processing Record 14 of Set 2 | ayagoz
# Processing Record 15 of Set 2 | tocopilla
# Processing Record 16 of Set 2 | solnechnyy
# Processing Record 17 of Set 2 | hay river
# Processing Record 18 of Set 2 | villavicencio
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | oleksandrivka
# Processing Record 21 of Set 2 | haines junction
# Processing Record 22 of Set 2 | sakakah
# Processing Record 23 of Set 2 | ouesso
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | schenefeld
# Processing Record 26 of Set 2 | tarut
# Processing Record 27 of Set 2 | clyde river
# Processing Record 28 of Set 2 | mwinilunga
# Processing Record 29 of Set 2 | gamba
# Processing Record 30 of Set 2 | russkaya polyana
# Processing Record 31 of Set 2 | kenai
# Processing Record 32 of Set 2 | ulladulla
# Processing Record 33 of Set 2 | port blair
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | nizhnevartovsk
# Processing Record 36 of Set 2 | ilulissat
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | key largo
# Processing Record 39 of Set 2 | inhambane
# Processing Record 40 of Set 2 | atasu
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | alofi
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | port hardy
# Processing Record 46 of Set 2 | taytay
# Processing Record 47 of Set 2 | leshukonskoye
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | chuy
# Processing Record 0 of Set 3 | lavrentiya
# Processing Record 1 of Set 3 | shirokiy
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | itamaraca
# Processing Record 4 of Set 3 | victoria
# Processing Record 5 of Set 3 | nioro
# Processing Record 6 of Set 3 | saraland
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | haimen
# Processing Record 9 of Set 3 | severo-kurilsk
# Processing Record 10 of Set 3 | muros
# Processing Record 11 of Set 3 | sao joao da barra
# Processing Record 12 of Set 3 | alyangula
# Processing Record 13 of Set 3 | jasper
# Processing Record 14 of Set 3 | richards bay
# Processing Record 15 of Set 3 | vuktyl
# Processing Record 16 of Set 3 | fairmount
# Processing Record 17 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 18 of Set 3 | aban
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | ostersund
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | polyany
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | half moon bay
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | shingu
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | yulara
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | levokumskoye
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | jiangmen
# Processing Record 34 of Set 3 | esperance
# Processing Record 35 of Set 3 | malinovoye ozero
# Processing Record 36 of Set 3 | geraldton
# Processing Record 37 of Set 3 | auki
# Processing Record 38 of Set 3 | shchors
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | tchibanga
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | bluff
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | takoradi
# Processing Record 45 of Set 3 | busselton
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 3 | klaksvik
# Processing Record 49 of Set 3 | chik
# Processing Record 0 of Set 4 | fort nelson
# Processing Record 1 of Set 4 | tuktoyaktuk
# Processing Record 2 of Set 4 | coulihaut
# City not found. Skipping...
# Processing Record 3 of Set 4 | norman wells
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | jalingo
# Processing Record 6 of Set 4 | port elizabeth
# Processing Record 7 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 8 of Set 4 | jawhar
# Processing Record 9 of Set 4 | riyadh
# Processing Record 10 of Set 4 | paita
# Processing Record 11 of Set 4 | linxia
# Processing Record 12 of Set 4 | salalah
# Processing Record 13 of Set 4 | tateyama
# Processing Record 14 of Set 4 | huarmey
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | ketchikan
# Processing Record 17 of Set 4 | fairbanks
# Processing Record 18 of Set 4 | ugoofaaru
# Processing Record 19 of Set 4 | ushumun
# Processing Record 20 of Set 4 | puerto del rosario
# Processing Record 21 of Set 4 | nancha
# Processing Record 22 of Set 4 | tabas
# Processing Record 23 of Set 4 | tommot
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | presidencia roque saenz pena
# Processing Record 26 of Set 4 | shumskiy
# Processing Record 27 of Set 4 | coquimbo
# Processing Record 28 of Set 4 | umm lajj
# Processing Record 29 of Set 4 | matinhos
# Processing Record 30 of Set 4 | bandarbeyla
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | mount isa
# Processing Record 33 of Set 4 | inhapim
# Processing Record 34 of Set 4 | kavieng
# Processing Record 35 of Set 4 | lethem
# Processing Record 36 of Set 4 | saint-joseph
# Processing Record 37 of Set 4 | teseney
# Processing Record 38 of Set 4 | sao jose da coroa grande
# Processing Record 39 of Set 4 | thompson
# Processing Record 40 of Set 4 | mount gambier
# Processing Record 41 of Set 4 | stryn
# Processing Record 42 of Set 4 | baisha
# Processing Record 43 of Set 4 | jamestown
# Processing Record 44 of Set 4 | vestmannaeyjar
# Processing Record 45 of Set 4 | saint-philippe
# Processing Record 46 of Set 4 | soligalich
# Processing Record 47 of Set 4 | codrington
# Processing Record 48 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 4 | nishihara
# Processing Record 0 of Set 5 | rio cuarto
# Processing Record 1 of Set 5 | padang
# Processing Record 2 of Set 5 | pangkalanbuun
# Processing Record 3 of Set 5 | sept-iles
# Processing Record 4 of Set 5 | derzhavinsk
# Processing Record 5 of Set 5 | sladkovo
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | aviles
# Processing Record 8 of Set 5 | mogadishu
# Processing Record 9 of Set 5 | klyuchi
# Processing Record 10 of Set 5 | koumac
# Processing Record 11 of Set 5 | san patricio
# Processing Record 12 of Set 5 | bartica
# Processing Record 13 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 14 of Set 5 | dunedin
# Processing Record 15 of Set 5 | pangnirtung
# Processing Record 16 of Set 5 | saint george
# Processing Record 17 of Set 5 | alice springs
# Processing Record 18 of Set 5 | vila velha
# Processing Record 19 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 5 | narsaq
# Processing Record 21 of Set 5 | karratha
# Processing Record 22 of Set 5 | esqueda
# Processing Record 23 of Set 5 | bacolod
# Processing Record 24 of Set 5 | wexford
# Processing Record 25 of Set 5 | naliya
# Processing Record 26 of Set 5 | casper
# Processing Record 27 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 28 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 5 | mackay
# Processing Record 30 of Set 5 | farah
# Processing Record 31 of Set 5 | saskylakh
# Processing Record 32 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 5 | constitucion
# Processing Record 34 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 35 of Set 5 | trairi
# Processing Record 36 of Set 5 | saint anthony
# Processing Record 37 of Set 5 | san lazaro
# Processing Record 38 of Set 5 | manta
# Processing Record 39 of Set 5 | beringovskiy
# Processing Record 40 of Set 5 | uniao
# Processing Record 41 of Set 5 | aklavik
# Processing Record 42 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 5 | beisfjord
# Processing Record 44 of Set 5 | ocos
# Processing Record 45 of Set 5 | butaritari
# Processing Record 46 of Set 5 | ambanja
# Processing Record 47 of Set 5 | tres lagoas
# Processing Record 48 of Set 5 | benguela
# Processing Record 49 of Set 5 | palmer
# Processing Record 0 of Set 6 | roald
# Processing Record 1 of Set 6 | mahibadhoo
# Processing Record 2 of Set 6 | sitka
# Processing Record 3 of Set 6 | namibe
# Processing Record 4 of Set 6 | asau
# Processing Record 5 of Set 6 | san mateo del mar
# Processing Record 6 of Set 6 | kiknur
# Processing Record 7 of Set 6 | alugan
# Processing Record 8 of Set 6 | kuhdasht
# Processing Record 9 of Set 6 | coxim
# Processing Record 10 of Set 6 | taoudenni
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | port macquarie
# Processing Record 13 of Set 6 | yeppoon
# Processing Record 14 of Set 6 | chancay
# Processing Record 15 of Set 6 | acapulco
# Processing Record 16 of Set 6 | maraa
# Processing Record 17 of Set 6 | skelleftea
# Processing Record 18 of Set 6 | polewali
# Processing Record 19 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 6 | cherskiy
# Processing Record 21 of Set 6 | dolni dabnik
# Processing Record 22 of Set 6 | saint-augustin
# Processing Record 23 of Set 6 | el tarra
# Processing Record 24 of Set 6 | sola
# Processing Record 25 of Set 6 | champerico
# Processing Record 26 of Set 6 | morant bay
# Processing Record 27 of Set 6 | mahebourg
# Processing Record 28 of Set 6 | mayo
# Processing Record 29 of Set 6 | lompoc
# Processing Record 30 of Set 6 | bowen
# Processing Record 31 of Set 6 | laguna
# Processing Record 32 of Set 6 | coihaique
# Processing Record 33 of Set 6 | saldanha
# Processing Record 34 of Set 6 | aleksandrov
# Processing Record 35 of Set 6 | shushtar
# Processing Record 36 of Set 6 | vardo
# Processing Record 37 of Set 6 | isangel
# Processing Record 38 of Set 6 | ixtapa
# Processing Record 39 of Set 6 | lorengau
# Processing Record 40 of Set 6 | puri
# Processing Record 41 of Set 6 | jacksonville
# Processing Record 42 of Set 6 | cascais
# Processing Record 43 of Set 6 | tarko-sale
# Processing Record 44 of Set 6 | lagunas
# Processing Record 45 of Set 6 | burnie
# Processing Record 46 of Set 6 | kirakira
# Processing Record 47 of Set 6 | ancud
# Processing Record 48 of Set 6 | mercedes
# Processing Record 49 of Set 6 | maniitsoq
# Processing Record 0 of Set 7 | pangai
# Processing Record 1 of Set 7 | concordia
# Processing Record 2 of Set 7 | caravelas
# Processing Record 3 of Set 7 | pontianak
# Processing Record 4 of Set 7 | kavaratti
# Processing Record 5 of Set 7 | bairiki
# Processing Record 6 of Set 7 | saint-georges
# Processing Record 7 of Set 7 | bubaque
# Processing Record 8 of Set 7 | belgrade
# Processing Record 9 of Set 7 | villamontes
# Processing Record 10 of Set 7 | nivala
# Processing Record 11 of Set 7 | marsa matruh
# Processing Record 12 of Set 7 | villareal
# Processing Record 13 of Set 7 | weatherford
# Processing Record 14 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 15 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 17 of Set 7 | chake chake
# Processing Record 18 of Set 7 | ambunti
# Processing Record 19 of Set 7 | bonthe
# Processing Record 20 of Set 7 | nueve de julio
# Processing Record 21 of Set 7 | karonga
# Processing Record 22 of Set 7 | stanislav
# Processing Record 23 of Set 7 | merauke
# Processing Record 24 of Set 7 | jarjis
# City not found. Skipping...
# Processing Record 25 of Set 7 | whitley bay
# Processing Record 26 of Set 7 | hambantota
# Processing Record 27 of Set 7 | liepaja
# Processing Record 28 of Set 7 | biaora
# Processing Record 29 of Set 7 | teknaf
# Processing Record 30 of Set 7 | omboue
# Processing Record 31 of Set 7 | jalu
# Processing Record 32 of Set 7 | comodoro rivadavia
# Processing Record 33 of Set 7 | robertsport
# Processing Record 34 of Set 7 | careiro da varzea
# Processing Record 35 of Set 7 | lashma
# Processing Record 36 of Set 7 | tatarsk
# Processing Record 37 of Set 7 | pecos
# Processing Record 38 of Set 7 | sena madureira
# Processing Record 39 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 7 | fort frances
# Processing Record 41 of Set 7 | jhalrapatan
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | avanigadda
# Processing Record 44 of Set 7 | nacogdoches
# Processing Record 45 of Set 7 | ovalle
# Processing Record 46 of Set 7 | zhigansk
# Processing Record 47 of Set 7 | samarai
# Processing Record 48 of Set 7 | puerto leguizamo
# Processing Record 49 of Set 7 | muzhi
# Processing Record 0 of Set 8 | strezhevoy
# Processing Record 1 of Set 8 | lambarene
# Processing Record 2 of Set 8 | port shepstone
# Processing Record 3 of Set 8 | imbituba
# Processing Record 4 of Set 8 | mayor pablo lagerenza
# Processing Record 5 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 8 | volchansk
# Processing Record 7 of Set 8 | alta floresta
# Processing Record 8 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 9 of Set 8 | san felipe
# Processing Record 10 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 8 | yar-sale
# Processing Record 12 of Set 8 | gushikawa
# Processing Record 13 of Set 8 | tirschenreuth
# Processing Record 14 of Set 8 | peru
# Processing Record 15 of Set 8 | xining
# Processing Record 16 of Set 8 | chimbote
# Processing Record 17 of Set 8 | indramayu
# Processing Record 18 of Set 8 | san juan de los morros
# Processing Record 19 of Set 8 | jumla
# Processing Record 20 of Set 8 | laramie
# Processing Record 21 of Set 8 | tres arroyos
# Processing Record 22 of Set 8 | montes claros
# Processing Record 23 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 8 | rio gallegos
# Processing Record 25 of Set 8 | neryungri
# Processing Record 26 of Set 8 | guicheng
# City not found. Skipping...
# Processing Record 27 of Set 8 | muravlenko
# Processing Record 28 of Set 8 | mount forest
# Processing Record 29 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 30 of Set 8 | la ronge
# Processing Record 31 of Set 8 | vila franca do campo
# Processing Record 32 of Set 8 | mancio lima
# Processing Record 33 of Set 8 | mazagao
# Processing Record 34 of Set 8 | bam
# Processing Record 35 of Set 8 | ascension
# Processing Record 36 of Set 8 | belyy yar
# Processing Record 37 of Set 8 | banepa
# Processing Record 38 of Set 8 | chernoistochinsk
# Processing Record 39 of Set 8 | ola
# Processing Record 40 of Set 8 | puerto baquerizo moreno
# Processing Record 41 of Set 8 | broome
# Processing Record 42 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 8 | ossora
# Processing Record 44 of Set 8 | zlitan
# Processing Record 45 of Set 8 | aswan
# Processing Record 46 of Set 8 | longyearbyen
# Processing Record 47 of Set 8 | curillo
# Processing Record 48 of Set 8 | smithers
# Processing Record 49 of Set 8 | noumea
# Processing Record 0 of Set 9 | pulandian
# Processing Record 1 of Set 9 | dawson creek
# Processing Record 2 of Set 9 | kindu
# Processing Record 3 of Set 9 | katsuura
# Processing Record 4 of Set 9 | teguise
# Processing Record 5 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 9 | olafsvik
# Processing Record 9 of Set 9 | cozumel
# Processing Record 10 of Set 9 | basingstoke
# Processing Record 11 of Set 9 | dali
# Processing Record 12 of Set 9 | pacifica
# Processing Record 13 of Set 9 | bonavista
# Processing Record 14 of Set 9 | bastia
# Processing Record 15 of Set 9 | the valley
# Processing Record 16 of Set 9 | boguchany
# Processing Record 17 of Set 9 | greymouth
# Processing Record 18 of Set 9 | verkhnyaya inta
# Processing Record 19 of Set 9 | beipiao
# Processing Record 20 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 9 | ruidoso
# Processing Record 22 of Set 9 | warsaw
# Processing Record 23 of Set 9 | torbay
# Processing Record 24 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 9 | tabuk
# Processing Record 26 of Set 9 | vallenar
# Processing Record 27 of Set 9 | wenatchee
# Processing Record 28 of Set 9 | sao filipe
# Processing Record 29 of Set 9 | severodvinsk
# Processing Record 30 of Set 9 | tigil
# Processing Record 31 of Set 9 | gorontalo
# Processing Record 32 of Set 9 | yialos
# City not found. Skipping...
# Processing Record 33 of Set 9 | ban phai
# Processing Record 34 of Set 9 | waingapu
# Processing Record 35 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 9 | banda aceh
# Processing Record 37 of Set 9 | manado
# Processing Record 38 of Set 9 | aloleng
# Processing Record 39 of Set 9 | gat
# Processing Record 40 of Set 9 | sinnamary
# Processing Record 41 of Set 9 | komsomolskiy
# Processing Record 42 of Set 9 | bahir dar
# Processing Record 43 of Set 9 | ratnagiri
# Processing Record 44 of Set 9 | tromso
# Processing Record 45 of Set 9 | tarakan
# Processing Record 46 of Set 9 | yasnyy
# Processing Record 47 of Set 9 | mitsamiouli
# Processing Record 48 of Set 9 | chiang klang
# Processing Record 49 of Set 9 | tuatapere
# Processing Record 0 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 10 | hobyo
# Processing Record 2 of Set 10 | bilibino
# Processing Record 3 of Set 10 | bardiyah
# Processing Record 4 of Set 10 | rocha
# Processing Record 5 of Set 10 | eirunepe
# Processing Record 6 of Set 10 | port keats
# Processing Record 7 of Set 10 | pipri
# Processing Record 8 of Set 10 | ferkessedougou
# Processing Record 9 of Set 10 | hualmay
# Processing Record 10 of Set 10 | bilma
# Processing Record 11 of Set 10 | itai
# Processing Record 12 of Set 10 | saint-pierre
# Processing Record 13 of Set 10 | khomutovo
# Processing Record 14 of Set 10 | dunmanway
# Processing Record 15 of Set 10 | quatre cocos
# Processing Record 16 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 10 | kendari
# Processing Record 18 of Set 10 | kyra
# Processing Record 19 of Set 10 | kibaya
# Processing Record 20 of Set 10 | santa cruz
# Processing Record 21 of Set 10 | kamenka
# Processing Record 22 of Set 10 | cidreira
# Processing Record 23 of Set 10 | nagycserkesz
# Processing Record 24 of Set 10 | tura
# Processing Record 25 of Set 10 | lata
# Processing Record 26 of Set 10 | tilichiki
# Processing Record 27 of Set 10 | namatanai
# Processing Record 28 of Set 10 | vegreville
# Processing Record 29 of Set 10 | egvekinot
# Processing Record 30 of Set 10 | marica
# Processing Record 31 of Set 10 | chenzhou
# Processing Record 32 of Set 10 | marzuq
# Processing Record 33 of Set 10 | marawi
# Processing Record 34 of Set 10 | fortuna
# Processing Record 35 of Set 10 | roblin
# Processing Record 36 of Set 10 | higuey
# City not found. Skipping...
# Processing Record 37 of Set 10 | ternate
# Processing Record 38 of Set 10 | gonen
# Processing Record 39 of Set 10 | kachiry
# Processing Record 40 of Set 10 | mtimbira
# Processing Record 41 of Set 10 | meridian
# Processing Record 42 of Set 10 | rio grande
# Processing Record 43 of Set 10 | backnang
# Processing Record 44 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 10 | calama
# Processing Record 46 of Set 10 | port-gentil
# Processing Record 47 of Set 10 | slave lake
# Processing Record 48 of Set 10 | kahului
# Processing Record 49 of Set 10 | anloga
# Processing Record 0 of Set 11 | lyuban
# Processing Record 1 of Set 11 | san cristobal
# Processing Record 2 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 11 | springbok
# Processing Record 4 of Set 11 | belmonte
# Processing Record 5 of Set 11 | menomonie
# Processing Record 6 of Set 11 | wajima
# Processing Record 7 of Set 11 | nazareno etla
# Processing Record 8 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 11 | maryville
# Processing Record 10 of Set 11 | los llanos de aridane
# Processing Record 11 of Set 11 | dezful
# Processing Record 12 of Set 11 | glace bay
# Processing Record 13 of Set 11 | karamken
# City not found. Skipping...
# Processing Record 14 of Set 11 | west bay
# Processing Record 15 of Set 11 | fort saint james
# Processing Record 16 of Set 11 | tautira
# Processing Record 17 of Set 11 | college
# Processing Record 18 of Set 11 | yorkton
# Processing Record 19 of Set 11 | belyye berega
# Processing Record 20 of Set 11 | biu
# Processing Record 21 of Set 11 | berlevag
# Processing Record 22 of Set 11 | veydelevka
# Processing Record 23 of Set 11 | mangaratiba
# Processing Record 24 of Set 11 | northam
# Processing Record 25 of Set 11 | kiama
# Processing Record 26 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 11 | ankazoabo
# Processing Record 28 of Set 11 | kolaras
# Processing Record 29 of Set 11 | atambua
# Processing Record 30 of Set 11 | kununurra
# Processing Record 31 of Set 11 | jacareacanga
# Processing Record 32 of Set 11 | tezu
# Processing Record 33 of Set 11 | henties bay
# Processing Record 34 of Set 11 | vilyuysk
# Processing Record 35 of Set 11 | sabha
# Processing Record 36 of Set 11 | westport
# Processing Record 37 of Set 11 | mawlaik
# Processing Record 38 of Set 11 | dianopolis
# City not found. Skipping...
# Processing Record 39 of Set 11 | torit
# Processing Record 40 of Set 11 | ankang
# Processing Record 41 of Set 11 | arroyo
# Processing Record 42 of Set 11 | aktau
# Processing Record 43 of Set 11 | jurado
# Processing Record 44 of Set 11 | havoysund
# Processing Record 45 of Set 11 | biak
# Processing Record 46 of Set 11 | margate
# Processing Record 47 of Set 11 | baculin
# Processing Record 48 of Set 11 | hofn
# Processing Record 49 of Set 11 | dhamrai
# Processing Record 0 of Set 12 | coahuayana
# Processing Record 1 of Set 12 | mitchell
# Processing Record 2 of Set 12 | lasa
# Processing Record 3 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 12 | nouna
# Processing Record 5 of Set 12 | terrace
# Processing Record 6 of Set 12 | bangui
# Processing Record 7 of Set 12 | gambela
# Processing Record 8 of Set 12 | andra
# Processing Record 9 of Set 12 | manokwari
# Processing Record 10 of Set 12 | qinzhou
# Processing Record 11 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 12 of Set 12 | cossato
# Processing Record 13 of Set 12 | sobolevo
# Processing Record 14 of Set 12 | pasighat
# Processing Record 15 of Set 12 | talnakh
# Processing Record 16 of Set 12 | monte alegre
# Processing Record 17 of Set 12 | kutum
# Processing Record 18 of Set 12 | sur
# Processing Record 19 of Set 12 | sabang
# Processing Record 20 of Set 12 | benghazi
# Processing Record 21 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 22 of Set 12 | stornoway
# Processing Record 23 of Set 12 | nantucket
# Processing Record 24 of Set 12 | atocha
# Processing Record 25 of Set 12 | bayburt
# Processing Record 26 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 12 | ouadda
# Processing Record 28 of Set 12 | arlit
# Processing Record 29 of Set 12 | innisfail
# Processing Record 30 of Set 12 | tabou
# Processing Record 31 of Set 12 | san rafael
# Processing Record 32 of Set 12 | meulaboh
# Processing Record 33 of Set 12 | luau
# Processing Record 34 of Set 12 | lakes entrance
# Processing Record 35 of Set 12 | khorixas
# Processing Record 36 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 12 | berasia
# Processing Record 38 of Set 12 | sopot
# Processing Record 39 of Set 12 | mirina
# City not found. Skipping...
# Processing Record 40 of Set 12 | nanga eboko
# Processing Record 41 of Set 12 | kijang
# Processing Record 42 of Set 12 | farim
# Processing Record 43 of Set 12 | chumikan
# Processing Record 44 of Set 12 | shaunavon
# Processing Record 45 of Set 12 | san carlos de bariloche
# Processing Record 46 of Set 12 | tarauaca
# Processing Record 47 of Set 12 | yarim
# Processing Record 48 of Set 12 | abashiri
# Processing Record 49 of Set 12 | xixiang
# Processing Record 0 of Set 13 | cockburn town
# Processing Record 1 of Set 13 | gandajika
# Processing Record 2 of Set 13 | lerwick
# Processing Record 3 of Set 13 | tutoia
# Processing Record 4 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 13 | marrakesh
# Processing Record 6 of Set 13 | olkhovka
# Processing Record 7 of Set 13 | hirara
# Processing Record 8 of Set 13 | muyezerskiy
# Processing Record 9 of Set 13 | tual
# Processing Record 10 of Set 13 | port augusta
# Processing Record 11 of Set 13 | nola
# Processing Record 12 of Set 13 | vostok
# Processing Record 13 of Set 13 | eregli
# Processing Record 14 of Set 13 | ayr
# Processing Record 15 of Set 13 | amberley
# Processing Record 16 of Set 13 | khasan
# Processing Record 17 of Set 13 | pansemal
# Processing Record 18 of Set 13 | newport
# Processing Record 19 of Set 13 | igarka
# Processing Record 20 of Set 13 | botwood
# Processing Record 21 of Set 13 | lipin bor
# Processing Record 22 of Set 13 | cururupu
# Processing Record 23 of Set 13 | ziguinchor
# Processing Record 24 of Set 13 | toora-khem
# Processing Record 25 of Set 13 | griffith
# Processing Record 26 of Set 13 | bulgan
# Processing Record 27 of Set 13 | garowe
# Processing Record 28 of Set 13 | talara
# Processing Record 29 of Set 13 | ginir
# Processing Record 30 of Set 13 | mumford
# Processing Record 31 of Set 13 | kisangani
# Processing Record 32 of Set 13 | pokhara
# Processing Record 33 of Set 13 | thibodaux
# Processing Record 34 of Set 13 | ostrovnoy
# Processing Record 35 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 36 of Set 13 | mutare
# Processing Record 37 of Set 13 | kruisfontein
# Processing Record 38 of Set 13 | manyana
# Processing Record 39 of Set 13 | rivadavia
# Processing Record 40 of Set 13 | oriximina
# Processing Record 41 of Set 13 | ust-omchug
# Processing Record 42 of Set 13 | tafresh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          585
# Lat           585
# Lng           585
# Max Temp      585
# Humidity      585
# Cloudiness    585
# Wind Speed    585
# Country       585
# Date          585
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Provideniya  64.3833 -173.3000     -2.09        65         100        6.71
# 1         Abha  18.2164   42.5053     51.62        87           0        0.00
# 2  Port Alfred -33.5906   26.8910     69.19        89         100        1.99
# 3   Nanortalik  60.1432  -45.2371      4.66        73          10       19.80
# 4      Rikitea -23.1203 -134.9692     79.97        68          10        9.95
#
#   Country        Date
# 0      RU  1675822214
# 1      SA  1675821989
# 2      ZA  1675822235
# 3      GL  1675822236
# 4      PF  1675822237

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        Provideniya  64.3833 -173.3000     -2.09        65         100
# 1               Abha  18.2164   42.5053     51.62        87           0
# 2        Port Alfred -33.5906   26.8910     69.19        89         100
# 3         Nanortalik  60.1432  -45.2371      4.66        73          10
# 4            Rikitea -23.1203 -134.9692     79.97        68          10
#
#          Wind Speed Country        Date
# City_ID
# 0              6.71      RU  1675822214
# 1              0.00      SA  1675821989
# 2              1.99      ZA  1675822235
# 3             19.80      GL  1675822236
# 4              9.95      PF  1675822237

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis = city_data_df['Lat']
y_axis = city_data_df['Max Temp']

f, ax = plt.subplots()
ax.scatter(x_axis,y_axis,edgecolors="black")

# Incorporate the other graph properties
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")
ax.set_title("City Max Latitude vs. Temperature (2023-02-07")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df['Lat']
y_axis = city_data_df['Humidity']


f, ax = plt.subplots()
ax.scatter(x_axis,y_axis,edgecolors="black")

# Incorporate the other graph properties
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity (%)")
ax.set_title("City Latitude vs. Humidity (2023-02-07)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df['Lat']
y_axis = city_data_df['Cloudiness']


f, ax = plt.subplots()
ax.scatter(x_axis,y_axis,edgecolors="black")

# Incorporate the other graph properties
ax.set_xlabel("Latitude")
ax.set_ylabel("Coudiness (%)")
ax.set_title("City Latitude vs. Cloudiness (2023-02-07)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df['Lat']
y_axis = city_data_df['Wind Speed']


f, ax = plt.subplots()
ax.scatter(x_axis,y_axis,edgecolors="black")

# Incorporate the other graph properties
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (mph)")
ax.set_title("City Latitude vs. Wind Speed (2023-02-07)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression(x_axis, y_axis):

    # Create variables to call from plots outside the function
    global regress_values, line_eq, rvalue
    
    #Calculate the linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    
    # Create line values
    regress_values = x_axis * slope + intercept
    
    # Return equation for annotation
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0               Provideniya  64.3833 -173.3000     -2.09        65
# 1                      Abha  18.2164   42.5053     51.62        87
# 3                Nanortalik  60.1432  -45.2371      4.66        73
# 5            Guerrero Negro  27.9769 -114.0611     64.89        30
# 7        Havre-Saint-Pierre  50.2334  -63.5986     15.04        79
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        6.71      RU  1675822214
# 1                 0        0.00      SA  1675821989
# 3                10       19.80      GL  1675822236
# 5                 0        6.46      MX  1675822239
# 7               100       12.55      CA  1675822239

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         Port Alfred -33.5906   26.8910     69.19        89         100
# 4             Rikitea -23.1203 -134.9692     79.97        68          10
# 6        Punta Arenas -53.1500  -70.9167     51.91        82           0
# 12              Vaini -21.2000 -175.2000     84.36        79          75
# 14            Ushuaia -54.8000  -68.3000     45.36        86          98
#
#          Wind Speed Country        Date
# City_ID
# 2              1.99      ZA  1675822235
# 4              9.95      PF  1675822237
# 6              4.61      CL  1675822054
# 12             6.91      TO  1675822243
# 14             6.29      AR  1675822173

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Max Temp']

# Run our linear_regression function declared above
linear_regression(x_axis, y_axis)

# Generate the plot
plt.scatter(x_axis, y_axis)
plt.title("Northern Hemisphere: Temperature (F) vs. Latitude (2023-02-07)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(2,-15),fontsize=15,color="red")
print(f"The correlation between latiude and temperature is: {round((rvalue**2),2)}")

plt.show()
# Out:
# The correlation between latiude and temperature is: 0.76

# %%
# Linear regression on Southern Hemisphere

x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Max Temp']

# Run our linear_regression function declared above
linear_regression(x_axis, y_axis)

# Generate the plot
plt.scatter(x_axis, y_axis)
plt.title("Southern Hemisphere: Temperature (F) vs. Latitude (2023-02-07)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-55,90),fontsize=15,color="red")
print(f"The correlation between latiude and temperature is: {round((rvalue**2),2)}")

plt.show()
# Out:
# The correlation between latiude and temperature is: 0.19

# %% [markdown]
# **Discussion about the linear relationship:** The temperatures increase as you get closer to the equator (longitude = 0), but the temperature variance is much higher in the norther hemisphere, with locations with a max temperature well below 0F, while in the souther hempisphere, temperatures remained above 50F. The cities pulled, did not fall as far south (minimum latitude under -60), while in the north, many locations fell above the 50 degree latitudinal threshold.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Humidity']

# Run our linear_regression function declared above
linear_regression(x_axis, y_axis)

# Generate the plot
plt.scatter(x_axis, y_axis)
plt.title("Northern Hemisphere: Humidity (%) vs. Latitude (2023-02-07)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="red")
print(f"The correlation between latiude and humidty is: {round((rvalue**2),2)}")

plt.show()
# Out:
# The correlation between latiude and humidty is: 0.18

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Humidity']

# Run our linear_regression function declared above
linear_regression(x_axis, y_axis)

# Generate the plot
plt.scatter(x_axis, y_axis)
plt.title("Southern Hemisphere: Humidity (%) vs. Latitude (2023-02-07)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-23,18),fontsize=15,color="red")
print(f"The correlation between latiude and humidty is: {round((rvalue**2),2)}")

plt.show()
# Out:
# The correlation between latiude and humidty is: 0.16

# %% [markdown]
# **Discussion about the linear relationship:** Loose correlation betwen the humidity and latitude in either hemisphere. The assumption would be a higher humidty level the closer to the equator, especially in the Northern Hempisphere, where it is currently winter, however, the inverse appears to be true with the humidty level climbing the futher north according to the trend line. This correlation is loose, however.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Cloudiness']

# Run our linear_regression function declared above
linear_regression(x_axis, y_axis)

# Generate the plot
plt.scatter(x_axis, y_axis)
plt.title("Northern Hemisphere: Cloudiness (%) vs. Latitude (2023-02-07)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(45,5),fontsize=15,color="red")
print(f"The correlation between latiude and cloudiness is: {round((rvalue**2),2)}")

plt.show()
# Out:
# The correlation between latiude and cloudiness is: 0.06

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Cloudiness']

# Run our linear_regression function declared above
linear_regression(x_axis, y_axis)

# Generate the plot
plt.scatter(x_axis, y_axis)
plt.title("Southern Hemisphere: Cloudiness (%) vs. Latitude (2023-02-07)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-55,90),fontsize=15,color="red")
print(f"The correlation between latiude and cloudines is: {round((rvalue**2),2)}")

plt.show()
# Out:
# The correlation between latiude and cloudines is: 0.16

# %% [markdown]
# **Discussion about the linear relationship:** There is very low correlation, if any, for the northern and southern hemispheres in this case. This is also highly vairable based on weather conditions on any given day.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Wind Speed']

# Run our linear_regression function declared above
linear_regression(x_axis, y_axis)

# Generate the plot
plt.scatter(x_axis, y_axis)
plt.title("Northern Hemisphere: Wind Speed (mph) vs. Latitude (2023-02-07)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(0,38),fontsize=15,color="red")
print(f"The correlation between latiude and wind speed is: {round((rvalue**2), 2)}")

plt.show()
# Out:
# The correlation between latiude and wind speed is: 0.02

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Wind Speed']

# Run our linear_regression function declared above
linear_regression(x_axis, y_axis)

# Generate the plot
plt.scatter(x_axis, y_axis)
plt.title("Southern Hemisphere: Wind Speed (mph) vs. Latitude (2023-02-07)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-55,23),fontsize=15,color="red")

print(f"The correlation between latiude and windspeed is: {round((rvalue**2),2)}")

plt.show()
# Out:
# The correlation between latiude and windspeed is: 0.12

# %% [markdown]
# **Discussion about the linear relationship:** Similar to cloudiness, this is also highly variable on any given day and there is virtually no correlation in either hempisphere.
